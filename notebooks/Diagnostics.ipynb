# %%
import timm
import torch
import weightwatcher as ww

from lib.model.multinet import DenseDrive

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
backbone = timm.create_model('convnext_atto', features_only=True, out_indices=(0,1,2,3), pretrained=True)
model = DenseDrive(backbone)
#model.backbone.requires_grad_(False)
print(count_parameters(model))
# Out:
# INFO:timm.models.helpers:Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/convnext_atto_d2-01bb0f51.pth)
# 4236622

# %%
watcher = ww.WeightWatcher(model=model)
details = watcher.analyze(plot=True)
# Out:
# INFO:weightwatcher:
#
# python      version 3.8.13 (default, Mar 28 2022, 06:59:08) [MSC v.1916 64 bit (AMD64)]
# numpy       version 1.22.3
# torch version 1.12.1+cpu
# INFO:weightwatcher:Saving all images to ww-img
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'plot': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'ww2x': False, 'vectors': False, 'smooth': None, 'stacked': False, 'svd_method': 'full_svd', 'fix_fingers': False, 'fit': 'power_law', 'sparsify': True, 'detX': False, 'mp_fit': False, 'min_evals': 50, 'max_evals': 10000, 'max_N': 10, 'tolerance': 1e-06, 'layer_ids_start': 0, 'add_biases': False, 'glorot_fit': False, 'layers': [], 'xmin_max': None}
# INFO:weightwatcher:Saving all images to ww-img
# INFO:weightwatcher:torch version 1.12.1+cpu
# INFO:weightwatcher:framework from model = 2
# python      version 3.8.13 (default, Mar 28 2022, 06:59:08) [MSC v.1916 64 bit (AMD64)]
# numpy       version 1.22.3
# torch version 1.12.1+cpu
